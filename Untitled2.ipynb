# %%
a =4
b =3

print(a/b)
# Out:
# 1.3333333333333333

# %%
c=1
d=2
print(c/d)
# Out:
# 0.5

# %%
e=7
f=3
print(e//f)
print(e%7)
print(e**f)
# Out:
# 2
# 0
# 343

# %%
quotient,remainder =divmod(5,2)
print(quotient,remainder)
# Out:
# 2 1

# %%
a=11+2
b=12-2
c=13*2
d=14/2
e=15**2
f=16//2
g=17%3

print(a,b,c,d,e,f,g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
i=3
i+=3
print(i)
i-=3
print(i)
i*=2
print(i)
i/=2
print(int (i))
i//=2
print(i)
i%=2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1.0
# 1.0

# %%
a = 10
b = 3
print("10 == 3 =>", a == b)
print("10 != 3 =>", a != b)
print("10 > 3 =>", a > b)
print("10 >= 3 =>", a >= b)
print("10 < 3 =>", a < b)
print("10 <= 3 =>", a <= b)
print()
# Out:
# 10 == 3 => False
# 10 != 3 => True
# 10 > 3 => True
# 10 >= 3 => True
# 10 < 3 => False
# 10 <= 3 => False

# %%
a=13
print(bin(a))
print(hex(a))
# Out:
# 0b1101
# 0xd

# %%
a=13
b=9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
# Out:
# 0b1101
# 0b1001
# 0b1001
# 9

# %%
a=13
b=9
print(bin(a))
print(bin(b))
print(bin(a|b))
print(a|b)
# Out:
# 0b1101
# 0b1001
# 0b1101
# 13

# %%
a=13
b=9
print(bin(a))
print(bin(b))
print(bin(a^b))
print(a^b)
# Out:
# 0b1101
# 0b1001
# 0b100
# 4
